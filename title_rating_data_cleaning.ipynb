# %% [markdown]
# <a href="https://colab.research.google.com/github/HussainPythonista/Collabrative-Recomentation-Syst/blob/main/title_rating_data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
#Loading data set in variable name
Rating_Dataset=pd.read_csv("/content/drive/MyDrive/title.ratings.tsv/data.tsv",sep="\t",on_bad_lines='skip')
Rating_Dataset.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2011
# 1  tt0000002            5.7       271
# 2  tt0000003            6.5      1931
# 3  tt0000004            5.4       179
# 4  tt0000005            6.2      2702
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['averageRating'].plot(kind='hist', bins=20, title='averageRating')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['numVotes'].plot(kind='hist', bins=20, title='numVotes')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
Rating_Dataset.shape
# Out:
# (1382915, 3)
